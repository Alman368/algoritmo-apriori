# %% [raw]
# # ♟️ Chess Association Rules Mining
#
# ## Descubriendo patrones ocultos en partidas de ajedrez usando el algoritmo Apriori
#
# ---
#
# ### 📋 Descripción del Proyecto
#
# Este análisis implementa el **algoritmo Apriori** para descubrir reglas de asociación en un extenso dataset de partidas de ajedrez de lichess.org. A través del análisis de más de 120,000 partidas, identificamos patrones significativos que revelan relaciones entre variables como el nivel de los jugadores, duración de las partidas y resultados.
#
# ### 🎯 Objetivos
#
# 1. **Implementación del Algoritmo Apriori**: Aplicación práctica para descubrir reglas de asociación
# 2. **Análisis de Patrones de Juego**: Identificación de relaciones entre variables categóricas
# 3. **Verificación de Hipótesis**: Validación estadística de reglas propuestas
# 4. **Comparación de Modalidades**: Análisis diferencial entre ritmos de juego
#
# ### 📊 Dataset
#
# - **Fuente**: lichess.org - Enero 2013
# - **Tamaño**: 121,332 partidas
# - **Modalidades analizadas**: Ajedrez rápido (600+0) y blitz (60+0)
#
# ---

# %%
# 📦 Instalación e importación de librerías
# !pip install mlxtend

# Importación de librerías principales
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import warnings
warnings.filterwarnings('ignore')

# Configuración de pandas para mejor visualización
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Configuración de estilo para gráficos
plt.style.use('default')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print('🎯 CHESS ASSOCIATION RULES MINING')
print('=' * 50)
print('📊 Dataset: lichess.org - 2013')
print('🔍 Algoritmo: Apriori')
print('=' * 50)
print('✅ Librerías cargadas exitosamente')

# %% [raw]
# ## 1. 📂 Carga y Exploración del Dataset
#
# ### Características del Dataset
#
# El dataset `lichess_games_2013-01.csv` contiene información sobre partidas de ajedrez del portal lichess.org, incluyendo:
#
# - **Información de jugadores**: Nombres y puntuaciones Elo
# - **Características de partida**: Resultado, control de tiempo, número de movimientos
# - **Información técnica**: Código ECO, apertura, tipo de finalización
#
# ### Proceso de Exploración
#
# Se realizará un análisis exploratorio completo de los datos para entender su estructura y calidad.

# %%
# 📊 Carga del dataset principal
print('🔄 Cargando datos...')
df = pd.read_csv('data/lichess_games_2013-01.csv')

# 📏 Análisis dimensional del dataset
print(f'\n📐 INFORMACIÓN DIMENSIONAL')
print(f'Dimensiones del dataset: {df.shape[0]:,} filas × {df.shape[1]} columnas')
print(f'Memoria utilizada: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB')

# 🏗️ Información estructural
print(f'\n🏗️ ESTRUCTURA DE DATOS')
print(df.info())

# 🔍 Análisis de valores faltantes
print(f'\n🔍 INTEGRIDAD DE DATOS')
print('Estado de valores faltantes por columna:')
missing_data = df.isnull().sum()
for col, missing in missing_data.items():
    if missing > 0:
        percentage = (missing / len(df)) * 100
        print(f'  ❌ {col}: {missing:,} ({percentage:.2f}%)')
    else:
        print(f'  ✅ {col}: Completo')

# 👀 Muestra de los primeros registros
print(f'\n👀 MUESTRA DE DATOS')
display(df.head())

print('\n✅ Dataset cargado exitosamente')
